# %%
vi json_file.json
cat json_file.json

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ADD JAR /home/acadgild/Downloads/hive-hcatalog-core-0.14.0.jar;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
CREATE TABLE json_table(name string, id bigint, skills array<string>)
    > ROW FORMAT SERDE 'org.apache.hive.hcatalog.data.JsonSerDe'
    > STORED AS TEXTFILE;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
LOAD DATA LOCAL INPATH '/home/acadgild/json_file.json'
    > INTO TABLE json_table;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT * FROM json_table;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT skills[0] FROM json_table;

# %% [markdown]
# ![image.png](data:image/png;base64,...)
