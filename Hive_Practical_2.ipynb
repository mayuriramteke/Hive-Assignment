# %%
vi employee.csv
cat employee.csv

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
CREATE TABLE employee
    > (id int,
    > name string,
    > skills array<string>)
    > ROW FORMAT DELIMITED 
    > FIELDS TERMINATED BY ','
    > COLLECTION ITEMS TERMINATED BY ':';

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
LOAD DATA LOCAL INPATH '/home/acadgild/material/employee.csv'
    > INTO TABLE employee;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT * FROM employee;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT size(skills),array_contains(skills,'HADOOP'),
    > sort_array(skills),concat_ws("|",skills) FROM employee;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT explode(skills) AS skills FROM 
    > employee;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT id,name,skill FROM employee LATERAL VIEW
    > explode(skills) skill_set AS skill;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
vi users.txt
cat users.txt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
vi locations.txt
cat locations.txt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT * FROM users ORDER BY name ASC;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT * FROM users SORT BY name ASC;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SET mapred.reduce.tasks=2;

# %%
SELECT * FROM users ORDER BY name ASC;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT * FROM users SORT BY name ASC;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT * FROM users DISTRIBUTE BY unit SORT BY name ASC;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT * FROM users CLUSTER BY unit;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
CREATE TABLE emp_details_partitioned
    > (emp_name string,
    > unit string,
    > exp int)
    > PARTITIONED BY(location string);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT * FROM emp_details;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
INSERT OVERWRITE TABLE emp_details_partitioned
    > PARTITION (location="mumbai") SELECT emp_name,unit,
    > exp FROM emp_details WHERE location="mumbai";

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SHOW PARTITIONS emp_details_partitioned;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
hdfs dfs -ls /user/hive/warehouse/test.db/emp_details_partitioned

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SET hive.exec.dynamic.partition.mode=nonstrict;

# %%
INSERT OVERWRITE TABLE emp_details_partitioned PARTITION (location) SELECT * 
    > FROM emp_details;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
 hdfs dfs -ls /user/hive/warehouse/test.db/emp_details_partitioned

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ALTER TABLE emp_details_partitioned DROP PARTITION(location="mumbai");

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
hdfs dfs -ls /user/hive/warehouse/test.db/emp_details_partitioned

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
 SELECT * FROM buck_users TABLESAMPLE 
    > (BUCKET 3 OUT OF 10 ON rand())s;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
CREATE TABLE buck_users
    > (id int,
    > name string,
    > salary int,
    > unit string)
    > CLUSTERED BY (id)
    > SORTED BY (id)
    > INTO 2 BUCKETS;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
 vi users.txt
cat users.txt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
CREATE TABLE users
    > (id int,
    > name string,
    > exp int,
    > unit string)
    > ROW FORMAT DELIMITED
    > FIELDS TERMINATED BY '\t';

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
 LOAD DATA LOCAL INPATH '/home/acadgild/material/users.txt'
    > INTO TABLE users;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SET hive.enforce.bucketing=true;

# %%
INSERT OVERWRITE TABLE buck_users 
    > SELECT * FROM users;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SHOW CREATE TABLE buck_users;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
hdfs dfs -ls /user/hive/warehouse/test.db/buck_users

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
hdfs dfs -cat /user/hive/warehouse/test.db/buck_users/000000_0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
hdfs dfs -cat /user/hive/warehouse/test.db/buck_users/000001_0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
CREATE TABLE locations(
    > id int,
    > location string)
    > ROW FORMAT DELIMITED 
    > FIELDS TERMINATED BY '\t';

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
LOAD DATA LOCAL INPATH '/home/acadgild/material/locations.txt' INTO
    > TABLE locations;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT * FROM locations;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT * FROM users u INNER JOIN locations l 
    > ON u.id=l.id;

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
SELECT * FROM users u LEFT OUTER JOIN locations l 
    > ON u.id=l.id;

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
SELECT * FROM users u RIGHT OUTER JOIN locations l 
    > ON u.id=l.id;

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
SELECT * FROM users u FULL OUTER JOIN locations l 
    > ON u.id=l.id;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
DROP TABLE users;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
 CREATE TABLE users(
    > id int,
    > name string,
    > salary int,
    > unit string)
    > ROW FORMAT DELIMITED
    > FIELDS TERMINATED BY '\t';

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
LOAD DATA LOCAL INPATH '/home/acadgild/material/users.txt'
    > INTO TABLE users;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT * FROM USERS;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT unit,MAX(salary) FROM users GROUP BY unit;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT id,name,salary,rank() OVER (PARTITION
    > BY unit ORDER BY salary DESC) AS rank FROM users;

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
SELECT id,name,salary,rank FROM
    > (SELECT id,name,salary,rank() OVER (PARTITION
    > BY unit ORDER BY salary DESC) AS rank FROM users) 
    > tmp WHERE rank=2;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ANALYZE TABLE users COMPUTE STATISTICS;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ANALYZE TABLE users COMPUTE STATISTICS FOR COLUMNS id,name,salary;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SET hive.cbo.enable=true;
SET hive.compute.query.using.stats=true;
SET hive.stats.fetch.column.stats=true;
SET hive.stats.fetch.partition.stats=true;
SELECT MAX(id) FROM users;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
EXPLAIN SELECT MAX(id) FROM users;

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
SET hive.vectorized.execution.enabled=true;
SET hive.vectorized.execution.reduce.enabled=true;
EXPLAIN SELECT MAX(id) FROM users;

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
